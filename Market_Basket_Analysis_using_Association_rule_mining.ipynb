# %% [markdown]
# <a href="https://colab.research.google.com/github/starlordsumit/DATA-ANALYSIS-PROJECTS/blob/main/Market_Basket_Analysis_using_Association_rule_mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Market Basket Analysis using Association rule mining

# %% [markdown]
# ## BY SUMIT RANJAN

# %% [markdown]
# Import Libraries

# %%
# !pip install apyori
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from apyori import apriori

# %%
df = pd.read_csv("/content/groceries.csv")

# %%
df.head()
# Out:
#                   1           2               3  ...   31   32  33
# 0    tropical fruit      yogurt          coffee  ...  NaN  NaN NaN
# 1        whole milk         NaN             NaN  ...  NaN  NaN NaN
# 2         pip fruit      yogurt   cream cheese   ...  NaN  NaN NaN
# 3  other vegetables  whole milk  condensed milk  ...  NaN  NaN NaN
# 4        whole milk      butter          yogurt  ...  NaN  NaN NaN
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (9835, 33)

# %% [markdown]
# ## Preprocessing on data

# %% [markdown]
# Here we need a data in form of list for Apriori Algorithm.

# %%
records = []
for i in range(1, 9835):
    records.append([str(df.values[i, j]) for j in range(0, 33)])

# %%
print(type(records))
# Out:
# <class 'list'>

# %% [markdown]
# ## Apriori Algorithm

# %% [markdown]
# *   Now time to apply algorithm on data.
# *   We have provide min_support, min_confidence, min_lift, and min length of sample-set for find rule.

# %% [markdown]
# ### Measure 1: Support.

# %% [markdown]
# This says how popular an itemset is, as measured by the proportion of transactions in which an itemset appears.

# %% [markdown]
# ### Measure 2: Confidence.

# %% [markdown]
# This says how likely item Y is purchased when item X is purchased, expressed as {X -> Y}. This is measured by the proportion of transactions with item X, in which item Y also appears.

# %% [markdown]
# ### Measure 3: Lift.

# %% [markdown]
# This says how likely item Y is purchased when item X is purchased, while controlling for how popular item Y is.

# %%
assoc_rule = apriori(records, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
assoc_result = list(assoc_rule)

# %% [markdown]
# ### How many relation derived

# %%
print("There are {} Relation derived.".format(len(assoc_result)))
# Out:
# There are 128 Relation derived.

# %% [markdown]
# ## Association Rules Derived

# %%
for i in range(0, len(assoc_result)):
    print(assoc_result[i][0])
# Out:
# frozenset({'baking powder', 'whipped/sour cream'})
# frozenset({'beef', 'root vegetables'})
# frozenset({'berries', 'whipped/sour cream'})
# frozenset({'bottled beer', 'liquor'})
# frozenset({'bottled beer', 'red/blush wine'})
# frozenset({'sugar', 'flour'})
# frozenset({'root vegetables', 'herbs'})
# frozenset({'sausage', 'sliced cheese'})
# frozenset({'nan', 'baking powder', 'whipped/sour cream'})
# frozenset({'nan', 'beef', 'root vegetables'})
# frozenset({'other vegetables', 'beef', 'root vegetables'})
# frozenset({'beef', 'rolls/buns', 'root vegetables'})
# frozenset({'beef', 'whole milk', 'root vegetables'})
# frozenset({'beef', 'root vegetables', 'yogurt'})
# frozenset({'nan', 'berries', 'whipped/sour cream'})
# frozenset({'bottled beer', 'nan', 'liquor'})
# frozenset({'bottled beer', 'red/blush wine', 'nan'})
# frozenset({'other vegetables', 'butter', 'domestic eggs'})
# frozenset({'butter', 'whole milk', 'domestic eggs'})
# ...

# %% [markdown]
# ## Rules Generated

# %%
for item in assoc_result:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    # second index of the inner list
    print("Support: " + str(item[1]))

    # third index of the list located at 0th
    # of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: baking powder -> whipped/sour cream
# Support: 0.004575960951799878
# Confidence: 0.25862068965517243
# Lift: 3.607483492296405
# ...
# Rule: beef -> root vegetables
# Support: 0.017388651616839536
# Confidence: 0.3313953488372093
# Lift: 3.0400577056577576
# ...
# Rule: berries -> whipped/sour cream
# Support: 0.009050233882448647
# Confidence: 0.27217125382262997
# Lift: 3.796499446938643
# ...
# Rule: bottled beer -> liquor
# Support: 0.004677648972950987
# Confidence: 0.42201834862385323
# Lift: 5.2400611620795114
# ...
# Rule: bottled beer -> red/blush wine
# Support: 0.004881025015253203
# Confidence: 0.25396825396825395
# Lift: 3.1534391534391535
# ...
# Rule: sugar -> flour
# Support: 0.004982713036404312
# Confidence: 0.28654970760233917
# Lift: 8.462251725409619
# ...
# Rule: root vegetables -> herbs
# Support: 0.007016473459426479
# Confidence: 0.43124999999999997
# Lift: 3.9560750932835815
# ...
# Rule: sausage -> sliced cheese
# Support: 0.007016473459426479
# Confidence: 0.2863070539419087
# ...
